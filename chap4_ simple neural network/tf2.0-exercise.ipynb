# %% [markdown]
# # Tensorflow2.0 小练习

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## 实现softmax函数

# %%
def softmax(x):
    ##########
    '''实现softmax函数,只要求对最后一维归一化,
    不允许用tf自带的softmax函数'''
    ##########
    # 数值稳定性:先减去最大值
    x_exp = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    # 对最后一维求和并归一化
    prob_x = x_exp / tf.reduce_sum(x_exp, axis=-1, keepdims=True)
    return prob_x

test_data = np.random.normal(size=[10, 5])
(softmax(test_data).numpy() - tf.nn.softmax(test_data, axis=-1).numpy())**2 <0.0001
# Out:
# array([[ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True]])

# %% [markdown]
# ## 实现sigmoid函数

# %%
def sigmoid(x):
    ##########
    '''实现sigmoid函数, 不允许用tf自带的sigmoid函数'''
    ##########
    # sigmoid(x) = 1 / (1 + exp(-x))
    prob_x = 1.0 / (1.0 + tf.exp(-x))
    return prob_x

test_data = np.random.normal(size=[10, 5])
(sigmoid(test_data).numpy() - tf.nn.sigmoid(test_data).numpy())**2 < 0.0001
# Out:
# array([[ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True]])

# %% [markdown]
# ## 实现 softmax 交叉熵loss函数

# %%
def softmax_ce(x, label):
    ##########
    '''实现 softmax 交叉熵loss函数, 不允许用tf自带的softmax_cross_entropy函数'''
    ##########
    # x 是经过softmax后的概率
    # 交叉熵: -sum(label * log(prob))
    # 添加小常数避免log(0)
    epsilon = 1e-12
    loss = -tf.reduce_mean(tf.reduce_sum(label * tf.math.log(x + epsilon), axis=-1))
    return loss

test_data = np.random.normal(size=[10, 5])
prob = tf.nn.softmax(test_data)
label = np.zeros_like(test_data)
label[np.arange(10), np.random.randint(0, 5, size=10)]=1.

((tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(label, test_data))
  - softmax_ce(prob, label))**2 < 0.0001).numpy()
# Out:
# np.True_

# %% [markdown]
# ## 实现 sigmoid 交叉熵loss函数

# %%
def sigmoid_ce(x, label):
    ##########
    '''实现 sigmoid 交叉熵loss函数, 不允许用tf自带的sigmoid_cross_entropy函数'''
    ##########
    # x 是经过sigmoid后的概率
    # 二分类交叉熵: -[label*log(prob) + (1-label)*log(1-prob)]
    # 添加小常数避免log(0)
    epsilon = 1e-12
    loss = -tf.reduce_mean(
        label * tf.math.log(x + epsilon) + (1.0 - label) * tf.math.log(1.0 - x + epsilon)
    )
    return loss

test_data = np.random.normal(size=[10])
prob = tf.nn.sigmoid(test_data)
label = np.random.randint(0, 2, 10).astype(test_data.dtype)
print (label)

((tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(label, test_data))- sigmoid_ce(prob, label))**2 < 0.0001).numpy()
# Out:
# [0. 1. 1. 1. 0. 0. 1. 0. 0. 0.]
# np.True_
